# %% [markdown]
# # Statistics

# %% [markdown]
# What Is Statistics
# ->  Statistics is the Scence of collecting,organizing,and analyzing data.

# %% [markdown]
#                                              TYPES F STATISTICS
#                                                      |
#                                             ------------------
#                                             |                 |
#                                         Descriptive          Inferential

# %% [markdown]
# 1) Descriptive Stats :- It Consist of Oraganizing and Sumerizing and Understanding Of the Data.

# %% [markdown]
# 2) Descriptive Stats :- Drawing the Conclusion OF the Data, Large Population that Choose Sample and test that Sample.

# %% [markdown]
# Sample & Population
#
# 1) Population:- Population is the large group of information. (N)
# 2) Sample:- Sample is the subset of the Population. (n)

# %% [markdown]
# Sampling Techniques:- The goal of the sampling that the create the sample of the entire population.

# %% [markdown]
# 1) Random Sampling Technique:- Choose the smple in the population is tandomly not choosing critiria of the sample.
#     denoting to (n).

# %% [markdown]
# 2) Stratified Sampling:- Select the Based on the characteristic that name is the (Streta) that names gives the technique.

# %% [markdown]
# 3) Systematic Sampling:- select systematic way to select kth element from the population.

# %% [markdown]
# 4) Canavience Sampling:- Voluntary Responce Sampling : it work on particular Domain

# %% [markdown]
# EXAMPLE OF SAMPLING:-
#      1) Exit Pole:- Random Sampling
#      2) Dieses INFO :- Convience Sampling
#      3) HouseHold Expenceise :- Strastified Sampling

# %% [raw]
#                                                  VARIEABLES
#                                                      |
#                                     -----------------------------------
#                                      |                                |
#                                 Quantitative                     Qualitative
#                                      |
#                              -----------------
#                              |               |
#                           Descrite      Continous

# %% [markdown]
# ## Quantitative
# 1) Descrite Varieable:- Hole Number meand like countable Numbers e.g:- Age- 45, bank accounts.
#
# 2) Continous Varieable:- Infinite Value not hole number e.g:- Height -145.233, salary, etc.

# %% [markdown]
# ## Qualitative

# %% [markdown]
# Quantitative:- Categorical Variable Dividing the categories
#     Examples:- Gender{Male and Female}

# %% [markdown]
# ### Measure of Central Tendency

# %% [markdown]
# 1) Mean(Avearage):- tolal number of sum divided by total number
# 2) Medium :- find midium number of the data
# 3) Mode :- find frequent item in the data.

# %% [markdown]
# ### EXAMPLE:-
# 1) Mean :-    {1,2,3,4,5} --->             15/5 = 3

# %% [markdown]
#   2).Medium:- {1,2,3,4,5} --> find middle element
#       step1:- order in accending order.
#       step2:- find middle element
#
#       But, the EVEN Number count in dataset so, middle two element are find mean fine Example:-- {1,2,3,4,5,6}--> middle element [3+4]/2=3.5

# %% [markdown]
# 3) Mode:-{1,2,2,2,3,3,3,4,4,4,4,5,5,6,7,8}--> Most frequent element {4}

# %% [markdown]
# ### Use Cases of Central Tendancy

# %% [markdown]
# 1) ouliers reduce ---> use Medium
# 2) categorical Feature----> use Mode like example(Gender that the categorical data)

# %% [markdown]
# # Measure of Desprision

# %% [markdown]
# 1)Varience:-- Varience is the spread of the data.

# %% [markdown]
# 2)Standard Deviation:--

# %% [markdown]
# ## Percentile

# %% [markdown]
# A percentile is the value below which a certain percentage of obeservation lie..

# %% [markdown]
# Dataset:- {2,2,3,4,5,5,5,6,7,8,8,8,8,8,9,9,10,11,11,12}
# question:- Calculate percentile rankin of the 10 ?
# ------>  percentile rank of 10 = below 10 values COUNT / Toatal Number * 100
#           = 16/20 * 100 = 80% (10 bol raha hai ki vo 80% entire distribution se bhada hai)
#
# Question:- percentile rank of the 12 ?
# --------> 19/20 * 100 = 95%
#
# Question:- What value of the exits at percentile rank of 25% ?
# --------> Value = percentage /100 *(n+1)
#                 25/100 * (20n+1) = 25/100 *21 = 5.5 <-----  what this value in the dataset so the 5.5 is that the index in dataset i.e {2,2,3,4,5,5,5,6,7,8,8,8,8,8,9,9,10,11,11,12}   -----------------> so the 5.5 index shows the 5 so 5indes both nighbours that the average and that Average  answer is that index answer suppose like this example [5+5/2] = 5 so  is the answer in the 25%

# %% [markdown]
# # OUTLIER

# %% [markdown]
# ## Outlier :-

# %% [markdown]
# Outlier is the extreme value in the dataset that suddenly changes like inappropiate element in the dataset that is the outlier

# %% [markdown]
# # How To Detect The Outlier?

# %% [markdown]
# ## BoxPlot
