# %% [markdown]
# # Probablity Distribution Function

# %% [markdown]
#                                 Probablity Distribution Function
#                                                 |
#                                 --------------------------------------
#                                 |                                    |
#                      probablity density function      probablity mass function

# %% [markdown]
# #### 1) Probablty Mass Function:- Used to Discreate Random variable

# %% [markdown]
# #### 2) Probablity Density Functio:- Used to Continous Random Variable

# %% [markdown]
# #### 3) Probality density function and Commulative Density Function
#
# PDF: value किती dense आहे ते सांगते
#
# CDF: त्या value पर्यंतची एकूण probability सांगते
