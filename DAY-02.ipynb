# %% [markdown]
# # Central Limit Therom

# %% [markdown]
# The Central Limit Theorem states that the sampling distribution of the sample mean tends toward a normal distribution as the sample size increases, regardless of the population distribution

# %% [markdown]
# Means that Sample size is the n>30 , so the find the mean that mean grether than 30 so the found the normal distribution and that normal distribution

# %% [markdown]
# ![images.png](attachment:e0ac7244-35d1-41bf-abd1-3f00db65cb6d.png)

# %% [markdown]
# केंद्रीय मर्यादा प्रमेय (Central Limit Theorem – CLT)
#
# 1️⃣ केंद्रीय मर्यादा प्रमेय काय आहे?
# कुठलाही डेटा (Normal, skewed, irregular) असला तरी जर नमुन्याचा आकार (sample size) मोठा असेल तर नमुना सरासरी (sample mean) चे वितरण Normal (घंटा-आकाराचे) होते — ह्यालाच केंद्रीय मर्यादा प्रमेय म्हणतात.

# %% [markdown]
# ### Use of CLT
#
# 1) Hypothesis Testing
# 2) Confidence Interval

# %% [markdown]
# ### Example
#
# 🎓 Student Marks Example
# पूर्ण कॉलेजचे marks random आहेत (normal नाहीत)
#
# प्रत्येक वेळेस 30 students निवडले
#
# त्यांच्या marks ची average काढली
#
# अनेक वेळा हे केल्यावर
# ➡️ Average marks → Normal distribution

# %% [markdown]
# # Log-Normal Distribution

# %% [markdown]
# <img src="https://www.investopedia.com/thmb/dmWOsjhPLEXqOnOFh7_0v3E4wUs%3D/1500x0/filters%3Ano_upscale%28%29%3Amax_bytes%28150000%29%3Astrip_icc%28%29/dotdash_Final_Log_Normal_Distribution_Nov_2020-01-fa015519559f4b128fef786c51841fb9.jpg" width="300" height="200" alt="description of image" />

# %% [markdown]
# Log Normal Distribution एखादा random variable X असा असेल की log(X) (म्हणजे ln X) हा Normal distribution follow करतो, तर X ला Log-Normal distribution म्हणतात.

# %% [markdown]
# ## Examples

# %% [markdown]
# Income / Salary (जास्त लोक medium income, थोडे फार high income)
#
# Stock prices
#
# House prices
#
# Time to complete a task
#
# Population growth, sales, website traffic
#
# 👉 कारण: हे सगळे multiply होत जातात, add नाही — म्हणून log-normal.

# %% [markdown]
# # Power Law Distribution

# %% [markdown]
# It is the 20%-80%--> RULE

# %% [markdown]
# Power law distribution is a distribution in which a small number of observations are extremely large, while the majority are small.

# %% [markdown]
# ### Example

# %% [markdown]
# Right-skewed data (income, sales, time)
#
# Variance constant नाही
#
# Normality हवी असेल तेव्हा

# %% [markdown]
# # Pareto Distribution

# %% [markdown]
# ![The-Long-Tail-Pareto-Distribution.png](attachment:f2228922-6639-4869-8283-2476f8a1a34d.png)

# %% [markdown]
# ![The-Long-Tail-Pareto-Distribution.png](attachment:f2228922-6639-4869-8283-2476f8a1a34d.png)

# %% [markdown]
# 👉 जिथे थोड्या लोकांकडे/घटनांकडे जास्तीत जास्त परिणाम असतो आणि बहुतेकांकडे खूप कमी — त्याला Pareto Distribution म्हणतात.

# %% [markdown]
# 👉 20% लोक → 80% result (अंदाजे)

# %% [markdown]
# ### Example:-[20%-80%]
#
# 1) 20 % of team responsible in deliverable 80% of project.
# 2) 20% product of amazon in responsible for 80% of sales.

# %% [markdown]
# # Hypothesis Testing

# %% [markdown]
# Hypothesis testing is a statistical method used to decide whether a given assumption about a population is true or false based on sample data.

# %% [markdown]
# ### Example:-
#
# Claim: “या coaching मुळे marks वाढतात”
#
# H₀: Coaching मुळे marks वाढत नाहीत
#
# H₁: Coaching मुळे marks वाढतात
#
# Data घेऊन test केला → decision घेतला.
